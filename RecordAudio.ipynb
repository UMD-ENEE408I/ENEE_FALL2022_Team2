# %%
# pip install sounddevice
# Out:
# Requirement already satisfied: sounddevice in c:\users\alexw\anaconda3\lib\site-packages (0.4.5)
# Requirement already satisfied: CFFI>=1.0 in c:\users\alexw\anaconda3\lib\site-packages (from sounddevice) (1.12.3)
# Requirement already satisfied: pycparser in c:\users\alexw\anaconda3\lib\site-packages (from CFFI>=1.0->sounddevice) (2.19)
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install wavio
# Out:
# Requirement already satisfied: wavio in c:\users\alexw\anaconda3\lib\site-packages (0.0.4)
# Requirement already satisfied: numpy>=1.6.0 in c:\users\alexw\anaconda3\lib\site-packages (from wavio) (1.16.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# install scipy if its not already

# %%
# import required libraries
import sounddevice as sd
from scipy.io.wavfile import write
import wavio as wv

from scipy.io import wavfile
  
# Sampling frequency
freq = 44100
  
# Recording duration (in seconds)
duration = 10
  
# Start recorder with the given values 
# of duration and sample frequency

recording = sd.rec(int(duration * freq), 
                   samplerate=freq, channels=2)
  
# Record audio for the given number of seconds
sd.wait()
  
# This will convert the NumPy array to an audio
# file with the given sampling frequency
write("recording0.wav", freq, recording)
  
#alternate method using wavio
# Convert the NumPy array to audio file
wv.write("recording1.wav", recording, freq, sampwidth=2)


output = wavfile.read('recording0.wav')
#print(output)
# Out:
# (44100, array([[ 0.0000000e+00,  0.0000000e+00],
#        [-3.0517578e-05,  0.0000000e+00],
#        [ 0.0000000e+00,  0.0000000e+00],
#        ...,
#        [-9.3383789e-03, -9.3383789e-03],
#        [-7.0800781e-03, -7.0495605e-03],
#        [-2.8991699e-03, -2.8991699e-03]], dtype=float32))

# %%
import numpy, scipy, matplotlib.pyplot as plt, IPython.display as ipd
import librosa, librosa.display
#import stanford_mir; stanford_mir.init()
from ipywidgets import interact
x, sr = librosa.load('recording1.wav')
ipd.Audio(x, rate=sr)
# Out:
# In C:\Users\AlexW\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\AlexW\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\AlexW\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\AlexW\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\AlexW\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\AlexW\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\AlexW\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\AlexW\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
